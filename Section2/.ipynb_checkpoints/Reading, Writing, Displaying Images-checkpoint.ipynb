# %%
import cv2

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %%
img = cv2.imread('./Section2Images/Image1.jpg')

cv2.imshow('Hello World', img)

cv2.waitKey()

cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
cv2.imwrite('./Section2Images/Section2Image1.png', img)
# Out:
# True

# %%
print(img.shape)
# Out:
# (830, 1245, 3)

# %%
print('Height of Image:', int(img.shape[0]), 'pixels')

print('Width of Image: ', int(img.shape[1]), 'pixels')
# Out:
# Height of Image: 830 pixels
# Width of Image:  1245 pixels
